# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("Amazon Sales data.csv")
data
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
#duplicated values 
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Region, Country, Item Type, Sales Channel, Order Priority, Order Date, Order ID, Ship Date, Units Sold, Unit Price, Unit Cost, Total Revenue, Total Cost, Total Profit]
# Index: []

# %%
#for column specific duplicated values in dataframe 
data[data.duplicated(['Country'])]
# Out:
#                                Region                Country        Item Type  \
# 22  Central America and the Caribbean               Honduras           Snacks
# 28                             Europe                 Norway        Beverages
# 37                 Sub-Saharan Africa             The Gambia             Meat
# 39                             Europe               Bulgaria  Office Supplies
# 42                 Sub-Saharan Africa             The Gambia           Cereal
# 44                               Asia                Myanmar          Clothes
# 47                             Europe            Switzerland    Personal Care
# 54                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 59                 Sub-Saharan Africa               Djibouti        Cosmetics
# 60              Australia and Oceania              Australia           Cereal
# 62                 Sub-Saharan Africa               Cameroon  Office Supplies
# ...

# %%
data[data.duplicated(['Country','Item Type'])]
# Out:
#                 Region                Country        Item Type Sales Channel  \
# 54  Sub-Saharan Africa  Sao Tome and Principe           Fruits       Offline
# 90  Sub-Saharan Africa           Sierra Leone  Office Supplies       Offline
# 98       North America                 Mexico    Personal Care       Offline
#
#    Order Priority Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 54              H  9/17/2013  508980977  10/24/2013        7637        9.33
# 90              H  12/6/2016  621386563  12/14/2016         948      651.21
# 98              M  7/30/2015  559427106    8/8/2015        5767       81.73
#
#     Unit Cost  Total Revenue  Total Cost  Total Profit
# 54       6.92       71253.21    52848.04      18405.17
# 90     524.96      617347.08   497662.08     119685.00
# 98      56.67      471336.91   326815.89     144521.02

# %%
#to drop the duplicate values
data.drop_duplicates()
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
data.drop_duplicates(["Country"])
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 89                             Europe               Slovenia        Beverages
# 93                             Europe                Romania        Cosmetics
# 94  Central America and the Caribbean              Nicaragua        Beverages
# 96                               Asia               Malaysia           Fruits
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %% [markdown]
# ### OUTLIERS IQR Inter Quartalile Range

# %%
#first quatile 25% #25 percentage mean is Q1
Q1=np.percentile(data['Unit Cost'],25)
Q1
# Out:
# 35.84

# %%
Q3=np.percentile(data['Unit Cost'],75)
Q3
# Out:
# 263.33

# %%
IQR= Q3-Q1
IQR
# Out:
# 227.48999999999998

# %%
low=Q1-1.5*IQR
upper= Q3+1.5*IQR

# %%
#empty list for storing ouliers
outliers=[]

# %%
# values greater then Q# and Lower than the Q1 store in list 
for i in data['Unit Cost']:
    if((i>upper) or (i<low)):
        outliers.append(i)

# %%
#no outliers in data
outliers
# Out:
# []

# %%
#now to remove the outliers from the lsit 
# all the not outlier values
for i in data['Unit Cost']:
    if i not in outliers:
        print(i)
# Out:
# 159.42
# 117.11
# 524.96
# 6.92
# 524.96
# 159.42
# 502.54
# 90.93
# 56.67
# 117.11
# 90.93
# 35.84
# 35.84
# 502.54
# 56.67
# 35.84
# 263.33
# 31.79
# 502.54
# 364.69
# 159.42
# 159.42
# 97.44
# 6.92
# 56.67
# 263.33
# 6.92
# 6.92
# 31.79
# 502.54
# 263.33
# 56.67
# 524.96
# 502.54
# 97.44
# 56.67
# 6.92
# 364.69
# 524.96
# 524.96
# 56.67
# 263.33
# 117.11
# 90.93
# 35.84
# 117.11
# 263.33
# 56.67
# 35.84
# 524.96
# 35.84
# 6.92
# 117.11
# 524.96
# 6.92
# 35.84
# 35.84
# 263.33
# 502.54
# 263.33
# 117.11
# 159.42
# 524.96
# 35.84
# 263.33
# 263.33
# 56.67
# 35.84
# 524.96
# 35.84
# 524.96
# 6.92
# 31.79
# 117.11
# 263.33
# 502.54
# 31.79
# 90.93
# 159.42
# 263.33
# 502.54
# 35.84
# 263.33
# 97.44
# 90.93
# 56.67
# 31.79
# 159.42
# 6.92
# 31.79
# 524.96
# 31.79
# 524.96
# 263.33
# 31.79
# 35.84
# 6.92
# 90.93
# 56.67
# 502.54

# %%
#store in the list non outlier values
nonoutliesre=[i for i in data['Unit Cost'] if i not in outliers]
